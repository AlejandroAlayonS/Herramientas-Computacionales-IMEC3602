# %% [markdown]
# # <div style="text-align: center"> Proyecto Final </div>
# <div style="text-align: center"> Alejandro Alayón Suárez - 201316083</div>
# ___

# %%
import numpy as np
import pylab
import matplotlib.pyplot as plt
import scipy
import imageio
import cv2
from scipy import misc
from scipy import ndimage
from skimage import data, color
from skimage.transform import hough_circle, hough_circle_peaks
from skimage.feature import canny
from skimage.draw import circle_perimeter
from skimage.util import img_as_ubyte

# %%
img = cv2.imread('Laminillas.tif')
crop = img[1250:1600,500:800]
plt.imshow(crop)
plt.show()

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
crop2 = thresh[1250:1600,500:800]
plt.imshow(crop2)
plt.show()

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel, iterations = 5)
crop2 = opening[520:570,1528:1559]
plt.imshow(opening)
plt.show()

# %%
crop4 = opening[1600:2000,1000:1200]
plt.imshow(crop4)
plt.show()

# %%
a=crop4.nonzero()
b=len(crop4)
c=len(crop4[0])
d=len(a[0])
por=100*d/(b*c)
d
# Out:
# 754

# %%
label_im, nb_labels =scipy.ndimage.label(opening)
sizes = (ndimage.sum(opening, label_im, range(nb_labels + 1)))/255
asdf=plt.hist(sizes,1000)
axes = plt.gca()
axes.set_xlim([0,5000])
plt.show()

# %%
#len(asdf[1])
len(asdf[1][1:])
mu, sigma = norm.fit(sizes)
# Out:
# 1000

# %%
plt.plot(asdf[1][1:], asdf[0], 'r--')
axes = plt.gca()
axes.set_xlim([0,5000])
plt.show()

# %%
from scipy.stats import norm
import matplotlib.mlab as mlab
# best fit of data
mu, sigma = norm.fit(sizes)
# the histogram of the data
n, bins, patches = plt.hist(sizes, 1000)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)
axes = plt.gca()
axes.set_xlim([0,5000])
plt.show()

# %%
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)
plt.show()

# %%
a=opening.nonzero()
b=len(opening)
c=len(opening[0])
d=len(a[0])
por=100*d/(b*c)
por
# Out:
# 7.738872059645379

# %%
crop = img[634:973,20:45]
plt.imshow(crop)
plt.show()

# %%
scale=((1/4.5)*1000)/(973-634)
scale
# Out:
# 0.6555227794165847

# %% [markdown]
# Tamaño mínimo para ser detectado por kernel 2

# %%
1533-1521
# Out:
# 12

# %%
12*scale
# Out:
# 7.866273352999016

# %%
(1559-1528)*scale
# Out:
# 20.321206161914123

# %% [markdown]
# Parámetros de entrada del programa
# - Imagen en formato tif
# - Escala o medida equivalente de cada pixel en $\mu m$
# - Tamaño mínimo de particula a considerar en $\mu m$

# %%
def imgimport(file):
    img = cv2.imread(file+'.tif')
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    return gray

# %%
def threshold(img_gray):
    ret, thresh = cv2.threshold(img_gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
    return thresh

# %%
def morf_opening(p_size,thresh_hold):
    m_size=0
    if p_size <= 8:
        m_size=2
    elif p_size <=21:
        m_size=3
    else:
        m_size=4
    kernel = np.ones((m_size,m_size),np.uint8)
    opening = cv2.morphologyEx(thresh_hold,cv2.MORPH_OPEN,kernel, iterations = 5)
    return opening

# %%
def coat_pct(opening):
    coord_pxl=opening.nonzero()
    lgth=len(opening)
    wdth=len(opening[0])
    coat_pixl=len(coord_pxl[0])
    pct=coat_pixl/(lgth*wdth)
    return pct

# %%
def size_n_nmbr(opening):
    label_im, nb_labels =scipy.ndimage.label(opening)
    sizes = ndimage.sum(opening, label_im, range(nb_labels + 1))
    sizes=sizes/255
    return nb_labels , sizes

# %% [markdown]
# Definir kernel con condicional y programar opening

# %%
gray=imgimport('Laminillas')
thresh=threshold(gray)
openi=morf_opening(9, thresh)
pct=coat_pct(openi)
numb, sizs =size_n_nmbr(openi)
plt.imshow(openi)
plt.show()
